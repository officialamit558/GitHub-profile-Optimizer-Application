# %%
# !pip install requests pandas matplotlib seaborn

# %% [markdown]
# ## Extracting User Information

# %% [markdown]
# ### Profile Information

# %%
#Profile Information

import requests

def get_profile_info(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}'
    response = requests.get(url, headers=headers)
    profile_data = response.json()
    return {
        'profile_name': profile_data['name'],
        'profile_id': profile_data['id'],
        'followers': profile_data['followers']
    }
#emilk
# Example usage
token = 'put_own_token_here'
username = 'officialamit558'
profile_info = get_profile_info(username, token)
print(profile_info)
# Out:
# {'profile_name': 'Amit Kumar', 'profile_id': 138309651, 'followers': 1}

# %% [markdown]
# ### Repository Information and most tech stack used

# %%
# Repository Information and most tech stack used


import requests
from collections import Counter
import base64
import json
from xml.etree import ElementTree as ET

def fetch_file_content(url, headers):
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        file_info = response.json()
        if 'content' in file_info:
            return base64.b64decode(file_info['content']).decode('utf-8')
    return None

def extract_dependencies(repo, headers):
    dependencies = []
    repo_name = repo['repo_name']
    owner = repo['owner']['login']

    # Check for package.json (JavaScript/Node.js)
    package_json_content = fetch_file_content(f'https://api.github.com/repos/{owner}/{repo_name}/contents/package.json', headers)
    if package_json_content:
        package_data = json.loads(package_json_content)
        if 'dependencies' in package_data:
            dependencies.extend(package_data['dependencies'].keys())
        if 'devDependencies' in package_data:
            dependencies.extend(package_data['devDependencies'].keys())

    # Check for requirements.txt (Python)
    requirements_content = fetch_file_content(f'https://api.github.com/repos/{owner}/{repo_name}/contents/requirements.txt', headers)
    if requirements_content:
        dependencies.extend(requirements_content.splitlines())

    # Check for Gemfile (Ruby)
    gemfile_content = fetch_file_content(f'https://api.github.com/repos/{owner}/{repo_name}/contents/Gemfile', headers)
    if gemfile_content:
        for line in gemfile_content.splitlines():
            if line.startswith('gem '):
                gem_name = line.split()[1].strip("'")
                dependencies.append(gem_name)

    # Check for pom.xml (Java)
    pom_xml_content = fetch_file_content(f'https://api.github.com/repos/{owner}/{repo_name}/contents/pom.xml', headers)
    if pom_xml_content:
        root = ET.fromstring(pom_xml_content)
        for dependency in root.findall('.//dependency'):
            group_id = dependency.find('groupId').text if dependency.find('groupId') is not None else ''
            artifact_id = dependency.find('artifactId').text if dependency.find('artifactId') is not None else ''
            dependencies.append(f'{group_id}:{artifact_id}')

    # Check for composer.json (PHP)
    composer_json_content = fetch_file_content(f'https://api.github.com/repos/{owner}/{repo_name}/contents/composer.json', headers)
    if composer_json_content:
        composer_data = json.loads(composer_json_content)
        if 'require' in composer_data:
            dependencies.extend(composer_data['require'].keys())

    # Check for go.mod (Go)
    go_mod_content = fetch_file_content(f'https://api.github.com/repos/{owner}/{repo_name}/contents/go.mod', headers)
    if go_mod_content:
        for line in go_mod_content.splitlines():
            if line.startswith('require'):
                dependency = line.split()[1]
                dependencies.append(dependency)

    return dependencies

def analyze_tech_stack(repos_info, token):
    headers = {'Authorization': f'token {token}'}
    tech_stack = []

    for repo in repos_info:
        # Primary language
        if repo['language']:
            tech_stack.append(repo['language'])

        # Dependencies from configuration files
        dependencies = extract_dependencies(repo, headers)
        tech_stack.extend(dependencies)

    tech_counter = Counter(tech_stack)
    most_common_tech = tech_counter.most_common(1)[0][0]

    # Sort tech stack by count in descending order
    sorted_tech_stack = tech_counter.most_common()

    return most_common_tech, sorted_tech_stack

def get_repositories_info(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}/repos'
    response = requests.get(url, headers=headers)
    repos_data = response.json()
    repos_info = []
    for repo in repos_data:
        repos_info.append({
            'repo_name': repo['name'],
            'language': repo['language'],
            'owner': repo['owner']  # Added owner info for dependency extraction
        })
    return repos_info

# Example usage
repos_info = get_repositories_info(username, token)
most_common_tech, sorted_tech_stack = analyze_tech_stack(repos_info, token)

for tech , count in sorted_tech_stack[:5]:
    print(tech)

print(f"Most common tech: {most_common_tech}")
print("Full tech stack analysis in descending order:")
for tech, count in sorted_tech_stack:
    print(f"{tech}: {count}")

for x in repos_info:
    print(x)
# Out:
# Jupyter Notebook
# Python
# streamlit
# numpy
# Flask==1.1.1
# Most common tech: Jupyter Notebook
# Full tech stack analysis in descending order:
# Jupyter Notebook: 13
# Python: 8
# streamlit: 3
# numpy: 3
# Flask==1.1.1: 2
# gunicorn==19.9.0: 2
# itsdangerous==1.1.0: 2
# Jinja2==2.10.1: 2
# MarkupSafe==1.1.1: 2
# Werkzeug==0.15.5: 2
# numpy>=1.9.2: 2
# scipy>=0.15.1: 2
# matplotlib>=1.4.3: 2
# pandas>=0.19: 2
# pandas: 2
# matplotlib: 2
# python-docx : 1
# PyPDF2: 1
# pdfplumber: 1
# HTML: 1
# scikit-learn== 1.2.2: 1
# flasgger==0.9.4: 1
# EJS: 1
# bcrypt: 1
# dotenv: 1
# ejs: 1
# express: 1
# express-session: 1
# mongoose: 1
# passport: 1
# passport-google-oauth20: 1
# passport-local: 1
# passport-local-mongoose: 1
# setuptools==57.5.0: 1
# pip==21.1.2: 1
# scikit-learn>=0.18: 1
# distutils: 1
# Flask: 1
# gunicorn: 1
# seaborn: 1
# sklearn: 1
# fastapi==0.111.0: 1
# gensim==4.3.2: 1
# joblib==1.4.2: 1
# numpy==1.26.4: 1
# pandas==2.2.2: 1
# pydantic==2.7.2: 1
# scikit_learn==1.5.0: 1
# tensorflow: 1
# cvzone: 1
# ultralytics: 1
# hydra-core: 1
# opencv-python: 1
# Pillow: 1
# PyYAML: 1
# requests: 1
# scipy: 1
# torch: 1
# torchvision: 1
# tqdm: 1
# filterpy: 1
# scikit-image: 1
# lap: 1
# PureBasic: 1
# {'repo_name': '-Data-Extraction-and-Sentiment-Analysis', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'absentieesm-data', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Akruti_to_Unicode', 'language': 'Python', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'amit_portfolio', 'language': 'HTML', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Bank_Note_Authentication_Model', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'BHP-Prediction', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Blog_Website', 'language': 'EJS', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Car-Price-Prediction', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Car_detection_model', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Cat_vs_Dog', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'cheack-spam', 'language': 'Python', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Convolutional-Neural-Network-Implementation', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Credit-card-fraud-detection', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'DESCRIBER', 'language': None, 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Digipplus', 'language': None, 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'DrowsyDriverDetection', 'language': None, 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Email_Classifier', 'language': 'Python', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'flaskr', 'language': 'Python', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'fruits_and_veg', 'language': 'Python', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Generate-profits-for-restaurent-', 'language': None, 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'image_segmentation_with_U-NET', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'ML-Task', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'MLFlow-Demo', 'language': 'Python', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'ML_Project', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'ML_Task_2', 'language': 'Jupyter Notebook', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Next_word_Predictor', 'language': None, 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'NLP-Text-Generation', 'language': 'Python', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'ObjectDetection', 'language': 'Python', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'People-Counting-Crowd-Density-Detection', 'language': None, 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}
# {'repo_name': 'Potato-disease-classification', 'language': 'PureBasic', 'owner': {'login': 'officialamit558', 'id': 138309651, 'node_id': 'U_kgDOCD5wEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/138309651?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/officialamit558', 'html_url': 'https://github.com/officialamit558', 'followers_url': 'https://api.github.com/users/officialamit558/followers', 'following_url': 'https://api.github.com/users/officialamit558/following{/other_user}', 'gists_url': 'https://api.github.com/users/officialamit558/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/officialamit558/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/officialamit558/subscriptions', 'organizations_url': 'https://api.github.com/users/officialamit558/orgs', 'repos_url': 'https://api.github.com/users/officialamit558/repos', 'events_url': 'https://api.github.com/users/officialamit558/events{/privacy}', 'received_events_url': 'https://api.github.com/users/officialamit558/received_events', 'type': 'User', 'site_admin': False}}

# %%
top_5_tech_stacks = [tech for tech, count in sorted_tech_stack[:5]]
print(top_5_tech_stacks)
# Out:
# ['Jupyter Notebook', 'Python', 'streamlit', 'numpy', 'Flask==1.1.1']

# %% [markdown]
# ### Analyzing and Recommending company

# %%
def recommend_companies(top_tech_stacks):
    tech_to_company = {
        'Jupyter Notebook': {
            'Data Scientist': ['Google', 'Dropbox', 'IBM', 'Coursera'],
            'Software Engineer': ['Instagram', 'IBM']
        },
        'JavaScript': {
            'Frontend Developer': ['Facebook', 'Netflix', 'Airbnb'],
            'Full Stack Developer': ['Google', 'Microsoft', 'Amazon'],
            'Backend Developer': ['Microsoft', 'Amazon']
        },
        'Java': {
            'Software Engineer': ['Amazon', 'LinkedIn', 'Uber', 'Oracle', 'IBM', 'Salesforce']
        },
        'C++': {
            'Software Engineer': ['Microsoft', 'Adobe', 'NVIDIA', 'Qualcomm', 'Apple', 'Intel']
        },
        'Python': {
            'Data Scientist': ['Google', 'Spotify', 'Quora', 'Reddit', 'Dropbox'],
            'Software Engineer': ['Pinterest']
        },
        'Ruby': {
            'Software Engineer': ['Shopify', 'Stripe', 'GitHub', 'Twitch', 'Basecamp']
        },
        'PHP': {
            'Software Engineer': ['Facebook', 'WordPress', 'Wikipedia', 'Flickr']
        },
        'Swift': {
            'iOS Developer': ['Apple', '9GAG', 'Spotify'],
            'Software Engineer': ['LinkedIn', 'Slack']
        },
        'Go': {
            'Software Engineer': ['Google', 'Twitch', 'Uber', 'Dropbox', 'SoundCloud']
        },
        'Rust': {
            'Software Engineer': ['Mozilla', 'Dropbox', 'Cloudflare', 'Discord']
        },
        'TypeScript': {
            'Software Engineer': ['Microsoft', 'Slack', 'Airbnb', 'Asana', 'Uber']
        },
        'Kotlin': {
            'Software Engineer': ['Google', 'Pinterest', 'Square', 'Trello', 'Corda']
        }
        # Add more mappings as needed
    }

    all_recommendations = {}
    for tech in top_tech_stacks:
        companies = tech_to_company.get(tech, ['No recommendations available'])
        all_recommendations[tech] = companies

    return all_recommendations

# Example usage
top_5_tech_stacks = [tech for tech, count in sorted_tech_stack[:5]]
company_recommendations = recommend_companies(top_5_tech_stacks)


print("Company recommendations based on top 5 tech stacks:")
for tech, companies in company_recommendations.items():
    print(f"\nTech: {tech} \nCompany: {companies}")
# Out:
# Company recommendations based on top 5 tech stacks:
#
# Tech: Jupyter Notebook
# Company: {'Data Scientist': ['Google', 'Dropbox', 'IBM', 'Coursera'], 'Software Engineer': ['Instagram', 'IBM']}
#
# Tech: Python
# Company: {'Data Scientist': ['Google', 'Spotify', 'Quora', 'Reddit', 'Dropbox'], 'Software Engineer': ['Pinterest']}
#
# Tech: streamlit
# Company: ['No recommendations available']
#
# Tech: numpy
# Company: ['No recommendations available']
#
# Tech: Flask==1.1.1
# Company: ['No recommendations available']

# %%
import requests

def get_company_recommendations_from_gemini(tech_stack, api_key):
    # Hypothetical correct endpoint
    url = "https://api.gemini.com/v1/techstack/recommendations"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "tech_stack": tech_stack
    }
    response = requests.post(url, headers=headers, json=payload)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}, {response.text}")
        return {"result": "error", "reason": response.status_code, "message": response.text}

# Example usage
api_key = "your_actual_gemini_api_key"
sorted_tech_stack = [('Python', 50), ('JavaScript', 40), ('Java', 30), ('C++', 20), ('Ruby', 10)]  # Example data
tech_stack = [tech for tech, count in sorted_tech_stack[:5]]
recommendations = get_company_recommendations_from_gemini(tech_stack, api_key)
print(recommendations)
# Out:
# Error: 404, {"result":"error","reason":"EndpointNotFound","message":"API entry point `/v1/techstack/recommendations` not found"}
# {'result': 'error', 'reason': 404, 'message': '{"result":"error","reason":"EndpointNotFound","message":"API entry point `/v1/techstack/recommendations` not found"}'}

# %%
top_5_tech_stacks = [tech for tech, count in sorted_tech_stack[:5]]
print(top_5_tech_stacks)
# Out:
# ['Jupyter Notebook', 'Python', 'streamlit', 'numpy', 'Flask==1.1.1']

# %% [markdown]
# ### Daily Contributions
# ```

# %%
# Daily Contributions


import requests
from datetime import datetime, timedelta

def get_daily_contributions(username, token):
    headers = {
        'Authorization': f'token {token}'
    }
    url = f'https://api.github.com/users/{username}/events'
    response = requests.get(url, headers=headers)
    events = response.json()

    contributions = {}
    today = datetime.now().strftime('%Y-%m-%d')
    yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

    for event in events:
        if event['type'] == 'PushEvent':
            event_date = event['created_at'][:10]  # Extracting only date part
            if event_date == today or event_date == yesterday:
                contributions[event_date] = contributions.get(event_date, 0) + 1

    return contributions

def maintain_streak(contributions):
    today = datetime.now().strftime('%Y-%m-%d')
    yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

    if today in contributions and yesterday in contributions:
        return True  # Streak maintained
    else:
        return False  # Streak broken

# Example usage
contributions = get_daily_contributions(username, token)
print("Daily contributions:", contributions)

streak_maintained = maintain_streak(contributions)
print("Streak maintained:", streak_maintained)
# Out:
# Daily contributions: {'2024-05-29': 3}
# Streak maintained: False

# %% [markdown]
# ###  Profile Improvement Tips

# %% [markdown]
# ### Profile Improvement Tips

# %%
#Profile Improvement Tips

import requests
from datetime import datetime

def suggest_profile_improvements(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}'
    response = requests.get(url, headers=headers)
    profile_data = response.json()

    tips = []

    # Check for profile picture
    if not profile_data.get('avatar_url'):
        tips.append('Add a professional profile picture.')

    # Check for bio
    if not profile_data.get('bio'):
        tips.append('Add a professional bio in the overview section.')

    # Check for blog or portfolio link
    if not profile_data.get('blog'):
        tips.append('Include links to personal projects and portfolio in your profile.')

    # Fetch repositories
    repos_url = f'https://api.github.com/users/{username}/repos'
    repos_response = requests.get(repos_url, headers=headers)
    repos_data = repos_response.json()

    # Check for repository updates
    recent_update = False
    now = datetime.now()
    for repo in repos_data:
        last_updated = datetime.strptime(repo['updated_at'], '%Y-%m-%dT%H:%M:%SZ')
        if (now - last_updated).days < 30:
            recent_update = True
            break
    if not recent_update:
        tips.append('Regularly update repositories with recent work.')

    # Check for commit messages
    commit_messages_descriptive = True
    for repo in repos_data:
        commits_url = f'https://api.github.com/repos/{username}/{repo["name"]}/commits'
        commits_response = requests.get(commits_url, headers=headers)
        commits_data = commits_response.json()
        for commit in commits_data:
            message = commit['commit']['message']
            if len(message.split()) < 3:  # simplistic check for descriptive messages
                commit_messages_descriptive = False
                break
        if not commit_messages_descriptive:
            break
    if not commit_messages_descriptive:
        tips.append('Use descriptive commit messages and maintain a consistent commit history.')

    # Check for open-source contributions
    events_url = f'https://api.github.com/users/{username}/events'
    events_response = requests.get(events_url, headers=headers)
    events_data = events_response.json()

    contributed_to_open_source = any(event['type'] == 'PullRequestEvent' for event in events_data)
    if not contributed_to_open_source:
        tips.append('Participate in open-source projects and contribute to community discussions.')

    # Check for pinned repositories
    pinned_repos_url = f'https://api.github.com/users/{username}/starred'
    pinned_repos_response = requests.get(pinned_repos_url, headers=headers)
    pinned_repos_data = pinned_repos_response.json()
    if not pinned_repos_data:
        tips.append('Pin key projects to showcase your skills at the top of your profile.')

    # Check for README files
    readme_missing = False
    for repo in repos_data:
        readme_url = f'https://api.github.com/repos/{username}/{repo["name"]}/readme'
        readme_response = requests.get(readme_url, headers=headers)
        if readme_response.status_code != 200:
            readme_missing = True
            break
    if readme_missing:
        tips.append('Ensure all repositories have well-documented README files.')

    # Check for educational information
    if not profile_data.get('company') and not profile_data.get('location'):
        tips.append('Add your educational background and relevant certifications to your profile.')

    # Check for stars and forks on repositories
    popular_repo = False
    for repo in repos_data:
        if repo['stargazers_count'] > 50 or repo['forks_count'] > 6:
            popular_repo = True
            break
    if not popular_repo:
        tips.append('Highlight your most popular repositories that have significant stars or forks.')

    # Check for repository topics
    missing_topics = False
    for repo in repos_data:
        topics_url = f'https://api.github.com/repos/{username}/{repo["name"]}/topics'
        topics_response = requests.get(topics_url, headers=headers)
        topics_data = topics_response.json()
        if not topics_data.get('names'):
            missing_topics = True
            break
    if missing_topics:
        tips.append('Add relevant topics to your repositories for better discoverability.')

    # Check for project descriptions
    missing_descriptions = False
    for repo in repos_data:
        if not repo['description']:
            missing_descriptions = True
            break
    if missing_descriptions:
        tips.append('Add detailed descriptions for each project to explain their purpose and functionality.')

    # Check for license information
    missing_license = False
    for repo in repos_data:
        license_url = f'https://api.github.com/repos/{username}/{repo["name"]}/license'
        license_response = requests.get(license_url, headers=headers)
        if license_response.status_code != 200:
            missing_license = True
            break
    if missing_license:
        tips.append('Ensure your repositories have appropriate licensing information.')

    # Check for coding challenges participation
    # This is a placeholder as we can't directly check external sites from GitHub API
    # You can integrate with other APIs such as LeetCode, HackerRank if they provide such functionality
    tips.append('Participate in coding challenges on platforms like LeetCode, HackerRank, etc. and add links to your profiles.')

    return tips

# Example usage
improvement_tips = suggest_profile_improvements(username, token)
for i in improvement_tips:
    print(i)
# Out:
# Add a professional bio in the overview section.
# Use descriptive commit messages and maintain a consistent commit history.
# Participate in open-source projects and contribute to community discussions.
# Ensure all repositories have well-documented README files.
# Highlight your most popular repositories that have significant stars or forks.
# Add relevant topics to your repositories for better discoverability.
# Add detailed descriptions for each project to explain their purpose and functionality.
# Ensure your repositories have appropriate licensing information.
# Participate in coding challenges on platforms like LeetCode, HackerRank, etc. and add links to your profiles.

# %% [markdown]
# ## Rating

# %%
# Rating

import requests
from datetime import datetime, timedelta
from bs4 import BeautifulSoup

def get_daily_contributions(username, token):
    headers = {
        'Authorization': f'token {token}'
    }
    url = f'https://api.github.com/users/{username}/events'
    response = requests.get(url, headers=headers)
    events = response.json()

    contributions = {}
    today = datetime.now().strftime('%Y-%m-%d')
    yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

    for event in events:
        if event['type'] == 'PushEvent':
            event_date = event['created_at'][:10]  # Extracting only date part
            if event_date == today or event_date == yesterday:
                contributions[event_date] = contributions.get(event_date, 0) + 1

    return contributions

def maintain_streak(contributions):
    today = datetime.now().strftime('%Y-%m-%d')
    yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

    if today in contributions and yesterday in contributions:
        return True  # Streak maintained
    else:
        return False  # Streak broken

def get_repositories_info(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}/repos'
    response = requests.get(url, headers=headers)
    repos_data = response.json()
    repos_info = []
    for repo in repos_data:
        repos_info.append({
            'repo_name': repo['name'],
            'language': repo['language'],
            'description': repo.get('description', 'No description available'),
            'tech_tools': repo.get('topics', []),
            'stargazers_count': repo['stargazers_count'],
            'forks_count': repo['forks_count']
        })
    return repos_info

def analyze_tech_stack(repos_info):
    from collections import Counter
    tech_stack = [repo['language'] for repo in repos_info if repo['language']]
    tech_counter = Counter(tech_stack)
    most_common_tech = tech_counter.most_common(1)[0][0]
    sorted_tech_stack = tech_counter.most_common()
    return most_common_tech, sorted_tech_stack

def rate_github_profile(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}'
    response = requests.get(url, headers=headers)
    profile_data = response.json()

    followers = profile_data['followers']
    public_repos = profile_data['public_repos']

    repos_info = get_repositories_info(username, token)

    total_stars = sum(repo['stargazers_count'] for repo in repos_info)
    total_forks = sum(repo['forks_count'] for repo in repos_info)

    contributions = get_daily_contributions(username, token)
    streak_maintained = maintain_streak(contributions)
     # Normalize each metric to a 0-1 scale before combining
    followers_score = min(followers / 1000, 1.0) * 4  # Max 4 points for followers
    public_repos_score = min(public_repos / 100, 1.0) * 3  # Max 3 points for public repos
    stars_score = min(total_stars / 500, 1.0) * 2  # Max 2 points for stars
    forks_score = min(total_forks / 200, 1.0) * 1  # Max 1 point for forks
    streak_score = 1 if streak_maintained else 0  # Max 1 point for streak

    rating = followers_score + public_repos_score + stars_score + forks_score + streak_score

    return round(min(rating, 10), 2)

# Example usage
# username = 'octocat'
# token = 'your_github_token'
contributions = get_daily_contributions(username, token)
print("Daily contributions:", contributions)

streak_maintained = maintain_streak(contributions)
print("Streak maintained:", streak_maintained)

repos_info = get_repositories_info(username, token)
most_common_tech, sorted_tech_stack = analyze_tech_stack(repos_info)
top_5_tech_stacks = [tech for tech, count in sorted_tech_stack[:5]]


rating = rate_github_profile(username, token)
print(f"GitHub Profile Rating: {rating}/10")
# Out:
# Daily contributions: {'2024-05-29': 3}
# Streak maintained: False
# GitHub Profile Rating: 1.12/10

# %% [markdown]
# ### All Output

# %%
def generate_recommendations(profile_info, most_common_tech, company_recommendations, improvement_tips):
    report = f"""
    GitHub Profile Analysis Report:
    ------------------------------
    Profile Name: {profile_info['profile_name']}
    Profile ID: {profile_info['profile_id']}
    Followers: {profile_info['followers']}

    Predominant Tech Stack: {most_common_tech}

    Recommended Companies:
    {', '.join(company_recommendations)}

    Profile Improvement Tips:
    {', '.join(improvement_tips)}
    """
    return report

# Example usage
recommendations_report = generate_recommendations(
    profile_info, most_common_tech, company_recommendations, improvement_tips
)
print(recommendations_report)
# Out:
#     GitHub Profile Analysis Report:
#     ------------------------------
#     Profile Name: Amit Kumar
#     Profile ID: 138309651
#     Followers: 1
#
#     Predominant Tech Stack: Jupyter Notebook
#
#     Recommended Companies:
#     Jupyter Notebook, Python, streamlit, numpy, Flask==1.1.1
#
#     Profile Improvement Tips:
#     Add a professional bio in the overview section., Use descriptive commit messages and maintain a consistent commit history., Participate in open-source projects and contribute to community discussions., Ensure all repositories have well-documented README files., Highlight your most popular repositories that have significant stars or forks., Add relevant topics to your repositories for better discoverability., Add detailed descriptions for each project to explain their purpose and functionality., Ensure your repositories have appropriate licensing information., Participate in coding challenges on platforms like LeetCode, HackerRank, etc. and add links to your profiles.

# %% [markdown]
# # Data collection from the GitHub

# %%
import requests

def get_github_usernames(token, since_id=0, per_page=100):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users?since={since_id}&per_page={per_page}'
    response = requests.get(url, headers=headers)
    users = response.json()
    return [user['login'] for user in users], users[-1]['id'] if users else None

# Example usage
# token = 'your_github_token'
usernames, last_id = get_github_usernames(token)
print(usernames)
# Out:
# ['mojombo', 'defunkt', 'pjhyett', 'wycats', 'ezmobius', 'ivey', 'evanphx', 'vanpelt', 'wayneeseguin', 'brynary', 'kevinclark', 'technoweenie', 'macournoyer', 'takeo', 'caged', 'topfunky', 'anotherjesse', 'roland', 'lukas', 'fanvsfan', 'tomtt', 'railsjitsu', 'nitay', 'kevwil', 'KirinDave', 'jamesgolick', 'atmos', 'errfree', 'mojodna', 'bmizerany', 'jnewland', 'joshknowles', 'hornbeck', 'jwhitmire', 'elbowdonkey', 'reinh', 'knzconnor', 'bs', 'rsanheim', 'schacon', 'uggedal', 'bruce', 'sam', 'mmower', 'abhay', 'rabble', 'benburkert', 'indirect', 'fearoffish', 'ry', 'engineyard', 'jsierles', 'tweibley', 'peimei', 'brixen', 'tmornini', 'outerim', 'daksis', 'sr', 'lifo', 'rsl', 'imownbey', 'dylanegan', 'jm', 'kmarsh', 'jvantuyl', 'BrianTheCoder', 'freeformz', 'hassox', 'automatthew', 'queso', 'lancecarlson', 'drnic', 'lukesutton', 'danwrong', 'HamptonMakes', 'jfrost', 'mattetti', 'ctennis', 'lawrencepit', 'marcjeanson', 'grempe', 'peterc', 'ministrycentered', 'afarnham', 'up_the_irons', 'cristibalan', 'heavysixer', 'brosner', 'danielmorrison', 'danielharan', 'kvnsmth', 'collectiveidea', 'canadaduane', 'corasaurus-hex', 'dstrelau', 'sunny', 'dkubb', 'jnicklas', 'richcollins']

# %%
import requests
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import joblib
import time

# %%
def get_github_usernames(token, since_id=0, per_page=100):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users?since={since_id}&per_page={per_page}'
    while True:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            users = response.json()
            return [user['login'] for user in users], users[-1]['id'] if users else None
        elif response.status_code == 403:
            print("Rate limit exceeded. Sleeping for 60 seconds...")
            time.sleep(60)
        else:
            response.raise_for_status()

def get_profile_info(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}'
    response = requests.get(url, headers=headers)
    return response.json()

def get_repositories_info(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}/repos'
    response = requests.get(url, headers=headers)
    repos_data = response.json()
    repos_info = []
    for repo in repos_data:
        repos_info.append({
            'repo_name': repo['name'],
            'language': repo['language'],
            'description': repo.get('description', 'No description available'),
            'tech_tools': repo.get('topics', []),
            'stargazers_count': repo['stargazers_count'],
            'forks_count': repo['forks_count']
        })
    return repos_info

def get_daily_contributions(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}/events'
    response = requests.get(url, headers=headers)
    events = response.json()

    contributions = {}
    today = datetime.now().strftime('%Y-%m-%d')
    yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

    for event in events:
        if event['type'] == 'PushEvent':
            event_date = event['created_at'][:10]  # Extracting only date part
            if event_date == today or event_date == yesterday:
                contributions[event_date] = contributions.get(event_date, 0) + 1

    return contributions

def maintain_streak(contributions):
    today = datetime.now().strftime('%Y-%m-%d')
    yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

    if today in contributions and yesterday in contributions:
        return 1  # Streak maintained
    else:
        return 0  # Streak broken

def rate_github_profile(username, token):
    headers = {'Authorization': f'token {token}'}
    url = f'https://api.github.com/users/{username}'
    response = requests.get(url, headers=headers)
    profile_data = response.json()

    followers = profile_data['followers']
    public_repos = profile_data['public_repos']

    repos_info = get_repositories_info(username, token)

    total_stars = sum(repo['stargazers_count'] for repo in repos_info)
    total_forks = sum(repo['forks_count'] for repo in repos_info)

    contributions = get_daily_contributions(username, token)
    streak_maintained = maintain_streak(contributions)

    # Normalize each metric to a 0-1 scale before combining
    followers_score = min(followers / 1000, 1.0) * 4  # Max 4 points for followers
    public_repos_score = min(public_repos / 100, 1.0) * 3  # Max 3 points for public repos
    stars_score = min(total_stars / 500, 1.0) * 2  # Max 2 points for stars
    forks_score = min(total_forks / 200, 1.0) * 1  # Max 1 point for forks
    streak_score = 1 if streak_maintained else 0  # Max 1 point for streak

    rating = followers_score + public_repos_score + stars_score + forks_score + streak_score

    return round(min(rating, 10), 2)

def collect_data_for_user(username, token):
    try:
        profile_info = get_profile_info(username, token)
        repos_info = get_repositories_info(username, token)
        contributions = get_daily_contributions(username, token)
        streak_maintained = maintain_streak(contributions)
        rating = rate_github_profile(username, token)

        return {
            'profile_name': profile_info['login'],
            'followers': profile_info['followers'],
            'public_repos': profile_info['public_repos'],
            'total_stars': sum(repo['stargazers_count'] for repo in repos_info),
            'total_forks': sum(repo['forks_count'] for repo in repos_info),
            'contributions_today': contributions.get(datetime.now().strftime('%Y-%m-%d'), 0),
            'streak_maintained': streak_maintained,
            'rating': rating
        }
    except Exception as e:
        print(f"Error collecting data for {username}: {e}")
        return None

def collect_data(usernames, token):
    data = []
    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = [executor.submit(collect_data_for_user, username, token) for username in usernames]
        for future in as_completed(futures):
            result = future.result()
            if result:
                data.append(result)
    return pd.DataFrame(data)

# Collect usernames
usernames = []
since_id = 0
while len(usernames) < 10000:
    new_usernames, since_id = get_github_usernames(token, since_id)
    usernames.extend(new_usernames)
    if not new_usernames:
        break
print(f"Collected {len(usernames)} usernames")

# Collect data for collected usernames
data = collect_data(usernames, token)
print(data.head())
# Out:
# Streaming output truncated to the last 5000 lines.
# Error collecting data for kasumix: string indices must be integers
# Error collecting data for dsklyut: string indices must be integers
# Error collecting data for jnovak: string indices must be integers
# Error collecting data for gakaki: string indices must be integers
# Error collecting data for aran: string indices must be integers
# Error collecting data for xitrium: string indices must be integers
# Error collecting data for patk-zz: string indices must be integers
# Error collecting data for dgolub: string indices must be integers
# Error collecting data for winton: string indices must be integers
# Error collecting data for zsolt: string indices must be integers
# Error collecting data for morizo: string indices must be integers
# Error collecting data for bkaney: string indices must be integers
# Error collecting data for PiTiLeZarD: string indices must be integers
# Error collecting data for ooodigi: string indices must be integers
# Error collecting data for nikolayr: string indices must be integers
# Error collecting data for postpostmodern: string indices must be integers
# Error collecting data for struan: string indices must be integers
# Error collecting data for moniker: string indices must be integers
# Error collecting data for AskNick: string indices must be integers
# Error collecting data for jsdk: string indices must be integers
# Error collecting data for al-skobelev: string indices must be integers
# Error collecting data for spikex: string indices must be integers
# Error collecting data for arya: string indices must be integers
# Error collecting data for mcandre: string indices must be integers
# Error collecting data for textgoeshere: string indices must be integers
# Error collecting data for z3bi: string indices must be integers
# Error collecting data for djtal: string indices must be integers
# Error collecting data for rrwhite: string indices must be integers
# Error collecting data for crux: string indices must be integers
# Error collecting data for ccthiel: string indices must be integers
# Error collecting data for benjaminoakes: string indices must be integers
# Error collecting data for scottm: string indices must be integers
# Error collecting data for RemyPorter: string indices must be integers
# Error collecting data for chewbranca: string indices must be integers
# Error collecting data for dhennessy: string indices must be integers
# Error collecting data for greatreorx: string indices must be integers
# Error collecting data for spkthed: string indices must be integers
# Error collecting data for elzo: string indices must be integers
# Error collecting data for mhoran: string indices must be integers
# Error collecting data for bulthuis: string indices must be integers
# Error collecting data for danielberlinger: string indices must be integers
# Error collecting data for richardkiss: string indices must be integers
# Error collecting data for ptb: string indices must be integers
# Error collecting data for ratmice: string indices must be integers
# Error collecting data for coroneos: string indices must be integers
# Error collecting data for briandeweese: string indices must be integers
# Error collecting data for deepakjois: string indices must be integers
# Error collecting data for butzopower: string indices must be integers
# Error collecting data for qnm: string indices must be integers
# Error collecting data for Gubbi: string indices must be integers
# Error collecting data for pkufranky: string indices must be integers
# Error collecting data for wagner: string indices must be integers
# Error collecting data for annalissac: string indices must be integers
# Error collecting data for davosian: string indices must be integers
# Error collecting data for liuming: string indices must be integers
# Error collecting data for jthingelstad: string indices must be integers
# Error collecting data for juno: string indices must be integers
# Error collecting data for magicdec: string indices must be integers
# Error collecting data for tomill: string indices must be integers
# Error collecting data for javan: string indices must be integers
# Error collecting data for snapper: string indices must be integers
# Error collecting data for laktek: string indices must be integers
# Error collecting data for goz-zz: string indices must be integers
# Error collecting data for joeunrue: string indices must be integers
# Error collecting data for bryan-xx: string indices must be integers
# Error collecting data for cowlibob: string indices must be integers
# Error collecting data for railsfactory: string indices must be integers
# Error collecting data for andreyvit: string indices must be integers
# Error collecting data for nelsonjchen: string indices must be integers
# Error collecting data for poteri: string indices must be integers
# Error collecting data for kodologist: string indices must be integers
# Error collecting data for nebogeo: string indices must be integers
# Error collecting data for hvirring: string indices must be integers
# Error collecting data for dokai: string indices must be integers
# Error collecting data for tolnem: string indices must be integers
# Error collecting data for mayoral: string indices must be integers
# Error collecting data for roidrage: string indices must be integers
# Error collecting data for rami: string indices must be integers
# Error collecting data for egogo: string indices must be integers
# Error collecting data for siannopollo: string indices must be integers
# Error collecting data for robertgaal: string indices must be integers
# Error collecting data for Gatonegro: string indices must be integers
# Error collecting data for rtack: string indices must be integers
# Error collecting data for newuni: string indices must be integers
# Error collecting data for chriseidhof: string indices must be integers
# Error collecting data for maurycy: string indices must be integers
# Error collecting data for dgl: string indices must be integers
# Error collecting data for aproxacs: string indices must be integers
# Error collecting data for weppos: string indices must be integers
# Error collecting data for maxschulze: string indices must be integers
# Error collecting data for pers: string indices must be integers
# Error collecting data for Vortex: string indices must be integers
# Error collecting data for mss: string indices must be integers
# Error collecting data for michaeljones: string indices must be integers
# Error collecting data for pocketarc: string indices must be integers
# Error collecting data for electronicbites: string indices must be integers
# Error collecting data for menno: string indices must be integers
# Error collecting data for Phoemuex: string indices must be integers
# Error collecting data for jamnut: string indices must be integers
# Error collecting data for namxam: string indices must be integers
# Error collecting data for alvin2ye: string indices must be integers
# Error collecting data for senny: string indices must be integers
# Error collecting data for jbfeldis: string indices must be integers
# Error collecting data for melchiorb: string indices must be integers
# Error collecting data for bluebit: string indices must be integers
# Error collecting data for miyamuko: string indices must be integers
# Error collecting data for rincewind: string indices must be integers
# Error collecting data for acousins: string indices must be integers
# Error collecting data for diegopolo: string indices must be integers
# Error collecting data for teg: string indices must be integers
# Error collecting data for gbesch: string indices must be integers
# Error collecting data for steder: string indices must be integers
# Error collecting data for chase: string indices must be integers
# Error collecting data for testk: string indices must be integers
# Error collecting data for daemonp: string indices must be integers
# Error collecting data for mitchellkotler: string indices must be integers
# Error collecting data for wchrisjohnson: string indices must be integers
# Error collecting data for tariel: string indices must be integers
# Error collecting data for kioopi: string indices must be integers
# Error collecting data for gabriele: string indices must be integers
# Error collecting data for sigxcpu: string indices must be integers
# Error collecting data for ssinghi: string indices must be integers
# Error collecting data for tobiashm: string indices must be integers
# Error collecting data for hackmp: string indices must be integers
# Error collecting data for fmancinelli: string indices must be integers
# Error collecting data for gbp: string indices must be integers
# Error collecting data for hypexr: string indices must be integers
# Error collecting data for ashmoran: string indices must be integers
# Error collecting data for tedkulp: string indices must be integers
# Error collecting data for kronos: string indices must be integers
# Error collecting data for bob-p: string indices must be integers
# Error collecting data for advany: string indices must be integers
# Error collecting data for gscalzo: string indices must be integers
# Error collecting data for khaosduke: string indices must be integers
# Error collecting data for carstenroselundberg: string indices must be integers
# Error collecting data for tallstreet: string indices must be integers
# Error collecting data for jpw27: string indices must be integers
# Error collecting data for shamer: string indices must be integers
# Error collecting data for aurels: string indices must be integers
# Error collecting data for soemirno: string indices must be integers
# Error collecting data for zlokomatic: string indices must be integers
# Error collecting data for davidwennergren: string indices must be integers
# Error collecting data for mathieul: string indices must be integers
# Error collecting data for cv: string indices must be integers
# Error collecting data for mihar: string indices must be integers
# Error collecting data for lylo: string indices must be integers
# Error collecting data for edsonmedina: string indices must be integers
# Error collecting data for jonbuda: string indices must be integers
# Error collecting data for cduan: string indices must be integers
# Error collecting data for cameronyule: string indices must be integers
# Error collecting data for dehora: string indices must be integers
# Error collecting data for cameron-xx: string indices must be integers
# Error collecting data for darwin: string indices must be integers
# Error collecting data for actraiser: string indices must be integers
# Error collecting data for stevenkovar: string indices must be integers
# Error collecting data for magicacid: string indices must be integers
# Error collecting data for labmeeting: string indices must be integers
# Error collecting data for atog: string indices must be integers
# Error collecting data for goldoraf: string indices must be integers
# Error collecting data for felipemathies: string indices must be integers
# Error collecting data for verlinden: string indices must be integers
# Error collecting data for greystate: string indices must be integers
# Error collecting data for ibloke: string indices must be integers
# Error collecting data for mruser: string indices must be integers
# Error collecting data for markkaganovich: string indices must be integers
# Error collecting data for ktangen: string indices must be integers
# Error collecting data for aquasync: string indices must be integers
# Error collecting data for samleb: string indices must be integers
# Error collecting data for Empact: string indices must be integers
# Error collecting data for eriiikk: string indices must be integers
# Error collecting data for CrashenX: string indices must be integers
# Error collecting data for mattr: string indices must be integers
# Error collecting data for epid: string indices must be integers
# Error collecting data for simonmichelmore: string indices must be integers
# Error collecting data for hui: string indices must be integers
# Error collecting data for jfine: string indices must be integers
# Error collecting data for rafaelss: string indices must be integers
# Error collecting data for sethladd: string indices must be integers
# Error collecting data for ericluo: string indices must be integers
# Error collecting data for andrewwillis: string indices must be integers
# Error collecting data for cameronp: string indices must be integers
# Error collecting data for pincefez: string indices must be integers
# Error collecting data for kingcu: string indices must be integers
# Error collecting data for ajpieri: string indices must be integers
# Error collecting data for keita: string indices must be integers
# Error collecting data for atkinson: string indices must be integers
# Error collecting data for lpgauth: string indices must be integers
# Error collecting data for brucep: string indices must be integers
# Error collecting data for scottmills: string indices must be integers
# Error collecting data for rubiety: string indices must be integers
# Error collecting data for arvanasse: string indices must be integers
# Error collecting data for hashemi: string indices must be integers
# Error collecting data for jpmontez: string indices must be integers
# Error collecting data for calebf: string indices must be integers
# Error collecting data for ericseijo: string indices must be integers
# Error collecting data for n3bulous: string indices must be integers
# Error collecting data for matiasjajaja: string indices must be integers
# Error collecting data for flextensity: string indices must be integers
# Error collecting data for ybakos: string indices must be integers
# Error collecting data for gdesign1: string indices must be integers
# Error collecting data for mciccone: string indices must be integers
# Error collecting data for jsjohnst: string indices must be integers
# Error collecting data for jasonbrummels: string indices must be integers
# Error collecting data for dongbin: string indices must be integers
# Error collecting data for scotfl: string indices must be integers
# Error collecting data for jack-xx: string indices must be integers
# Error collecting data for standino: string indices must be integers
# Error collecting data for ctwise: string indices must be integers
# Error collecting data for azambuja: string indices must be integers
# Error collecting data for sephlietz: string indices must be integers
# Error collecting data for harish: string indices must be integers
# Error collecting data for sgmac: string indices must be integers
# Error collecting data for teki: string indices must be integers
# Error collecting data for xenoterracide: string indices must be integers
# Error collecting data for thekvn: string indices must be integers
# Error collecting data for huacnlee: string indices must be integers
# Error collecting data for deadprogram: string indices must be integers
# Error collecting data for deadpogrammer: string indices must be integers
# Error collecting data for hopkinsd: string indices must be integers
# Error collecting data for bobes: string indices must be integers
# Error collecting data for fabianb: string indices must be integers
# Error collecting data for marcusramberg: string indices must be integers
# Error collecting data for gabrioserbelloni: string indices must be integers
# Error collecting data for jon5stamos5: string indices must be integers
# Error collecting data for torstenschuenemann: string indices must be integers
# Error collecting data for krishna2: string indices must be integers
# Error collecting data for raeson: string indices must be integers
# Error collecting data for mc: string indices must be integers
# Error collecting data for nicolaskoenig: string indices must be integers
# Error collecting data for kogakure: string indices must be integers
# Error collecting data for IceskYsl: string indices must be integers
# Error collecting data for tomklaasen: string indices must be integers
# Error collecting data for abanger: string indices must be integersError collecting data for ricardohead: string indices must be integers
#
# Error collecting data for kmaddu: string indices must be integers
# Error collecting data for taansen: string indices must be integers
# Error collecting data for psst: string indices must be integers
# Error collecting data for kamk: string indices must be integers
# Error collecting data for IanEsling: string indices must be integers
# Error collecting data for fabiobeta: string indices must be integers
# Error collecting data for stevesims: string indices must be integers
# Error collecting data for petehindle: string indices must be integers
# Error collecting data for np: string indices must be integers
# Error collecting data for elektronaut: string indices must be integers
# Error collecting data for kabus: string indices must be integers
# Error collecting data for gavinmcfarland: string indices must be integers
# Error collecting data for HamiltonHandbag: string indices must be integers
# Error collecting data for boticello: string indices must be integers
# Error collecting data for arne: string indices must be integers
# Error collecting data for exploreapps: string indices must be integers
# Error collecting data for rubaidh: string indices must be integers
# Error collecting data for PerPlougHansen: string indices must be integers
# Error collecting data for alext: string indices must be integers
# Error collecting data for arnee: string indices must be integers
# Error collecting data for matthewfallshaw: string indices must be integers
# Error collecting data for rubstar: string indices must be integers
# Error collecting data for twei55: string indices must be integers
# Error collecting data for jgarside: string indices must be integers
# Error collecting data for kuroda: string indices must be integers
# Error collecting data for impudite: string indices must be integers
# Error collecting data for rafaelgaspar: string indices must be integers
# Error collecting data for ohm: string indices must be integers
# Error collecting data for christkv: string indices must be integers
# Error collecting data for sctv: string indices must be integers
# Error collecting data for julien: string indices must be integers
# Error collecting data for esmk: string indices must be integers
# Error collecting data for serdar: string indices must be integers
# Error collecting data for staaky: string indices must be integers
# Error collecting data for beyoumedia: string indices must be integers
# Error collecting data for peterwald: string indices must be integers
# Error collecting data for carlsi: string indices must be integers
# Error collecting data for spainvictor: string indices must be integers
# Error collecting data for adeagman: string indices must be integers
# Error collecting data for fjfish: string indices must be integers
# Error collecting data for kas84: string indices must be integers
# Error collecting data for richardtifelt: string indices must be integers
# Error collecting data for darragh: string indices must be integers
# Error collecting data for jschumann: string indices must be integers
# Error collecting data for excentric: string indices must be integers
# Error collecting data for smetana: string indices must be integers
# Error collecting data for pamalite: string indices must be integers
# Error collecting data for letterj: string indices must be integers
# Error collecting data for yrcjaya: string indices must be integers
# Error collecting data for wouter: string indices must be integers
# Error collecting data for kubicek: string indices must be integers
# Error collecting data for cgrayson: string indices must be integers
# Error collecting data for nalanj: string indices must be integers
# Error collecting data for patrickreiner: string indices must be integers
# Error collecting data for vbaluch: string indices must be integers
# Error collecting data for pureyoda: string indices must be integers
# Error collecting data for lennysan: string indices must be integers
# Error collecting data for gtd: string indices must be integers
# Error collecting data for joshu: string indices must be integers
# Error collecting data for benmorrow: string indices must be integers
# Error collecting data for jeffboulet: string indices must be integers
# Error collecting data for EvanDotPro: string indices must be integers
# Error collecting data for travisennis: string indices must be integers
# Error collecting data for evocateur: string indices must be integers
# Error collecting data for sole: string indices must be integers
# Error collecting data for herval: string indices must be integers
# Error collecting data for jmccarthy: string indices must be integers
# Error collecting data for WhiteMagic: string indices must be integers
# Error collecting data for Th0ma5: string indices must be integers
# Error collecting data for wentsul: string indices must be integers
# Error collecting data for beyama: string indices must be integers
# Error collecting data for chadb: string indices must be integers
# Error collecting data for rubymerchant: string indices must be integers
# Error collecting data for zeroeth: string indices must be integers
# Error collecting data for gereth: string indices must be integers
# Error collecting data for PCoulton: string indices must be integers
# Error collecting data for saki: string indices must be integers
# Error collecting data for vincent: string indices must be integers
# Error collecting data for gregoriomunoz: string indices must be integers
# Error collecting data for thynctank: string indices must be integers
# Error collecting data for tamalw: string indices must be integers
# Error collecting data for michaeldwan: string indices must be integers
# Error collecting data for rogerf: string indices must be integers
# Error collecting data for jr: string indices must be integers
# Error collecting data for rgcottrell: string indices must be integers
# Error collecting data for PJnes: string indices must be integers
# Error collecting data for heri: string indices must be integers
# Error collecting data for ukalo: string indices must be integers
# Error collecting data for theRocket: string indices must be integers
# Error collecting data for purcell: string indices must be integers
# Error collecting data for unlobito: string indices must be integers
# Error collecting data for romaind: string indices must be integers
# Error collecting data for JEG2: string indices must be integers
# Error collecting data for ryanking: string indices must be integers
# Error collecting data for mcarlson: string indices must be integers
# Error collecting data for eppsilon: string indices must be integers
# Error collecting data for sid137: string indices must be integers
# Error collecting data for mikejones: string indices must be integers
# Error collecting data for drzal: string indices must be integers
# Error collecting data for mkruisselbrink: string indices must be integers
# Error collecting data for Flink: string indices must be integers
# Error collecting data for JonBeh: string indices must be integers
# Error collecting data for tombagby: string indices must be integers
# Error collecting data for silberman: string indices must be integers
# Error collecting data for gsl: string indices must be integers
# Error collecting data for moos3: string indices must be integers
# Error collecting data for pjstadig: string indices must be integers
# Error collecting data for gebloom: string indices must be integers
# Error collecting data for kdemanawa: string indices must be integers
# Error collecting data for faustog: string indices must be integers
# Error collecting data for caraza: string indices must be integers
# Error collecting data for tuomasjjrasanen: string indices must be integers
# Error collecting data for noelrappin: string indices must be integers
# Error collecting data for rvanmelle: string indices must be integers
# Error collecting data for jlouis: string indices must be integers
# Error collecting data for marbiano: string indices must be integers
# Error collecting data for redsnapper8t8: string indices must be integers
# Error collecting data for bsunarjo: string indices must be integers
# Error collecting data for ryannguyen: string indices must be integers
# Error collecting data for ivo: string indices must be integers
# Error collecting data for dares6: string indices must be integers
# Error collecting data for amitrathore: string indices must be integers
# Error collecting data for akessler: string indices must be integers
# Error collecting data for JimDabell: string indices must be integers
# Error collecting data for rguiu: string indices must be integers
# Error collecting data for javache: string indices must be integers
# Error collecting data for Cinal: string indices must be integers
# Error collecting data for christianromney: string indices must be integers
# Error collecting data for mlinville: string indices must be integers
# Error collecting data for joergd: string indices must be integers
# Error collecting data for aviv-xx: string indices must be integers
# Error collecting data for rharlos2: string indices must be integers
# Error collecting data for mfb82: string indices must be integers
# Error collecting data for GordonRobertson: string indices must be integers
# Error collecting data for moebius: string indices must be integers
# Error collecting data for holger: string indices must be integers
# Error collecting data for jeffbski: string indices must be integers
# Error collecting data for ryansobol: string indices must be integers
# Error collecting data for benefactual: string indices must be integers
# Error collecting data for misterbrandt: string indices must be integers
# Error collecting data for halcyon: string indices must be integers
# Error collecting data for cstoner: string indices must be integers
# Error collecting data for jserpieters: string indices must be integers
# Error collecting data for niftypixels: string indices must be integers
# Error collecting data for jshadyjlo: string indices must be integers
# Error collecting data for aufrank: string indices must be integers
# Error collecting data for neojin: string indices must be integers
# Error collecting data for jzajpt: string indices must be integers
# Error collecting data for lurcio: string indices must be integers
# Error collecting data for bertux: string indices must be integers
# Error collecting data for danielslz: string indices must be integers
# Error collecting data for buzkall: string indices must be integers
# Error collecting data for uzytkownik: string indices must be integers
# Error collecting data for xymetry: string indices must be integers
# Error collecting data for martinschweitzer: string indices must be integers
# Error collecting data for joanbarrull: string indices must be integers
# Error collecting data for goofmint: string indices must be integers
# Error collecting data for jborder: string indices must be integers
# Error collecting data for now: string indices must be integers
# Error collecting data for bradpurchase: string indices must be integers
# Error collecting data for poor666: string indices must be integers
# Error collecting data for cafc79: string indices must be integers
# Error collecting data for joshsmoore: string indices must be integers
# Error collecting data for shellreef: string indices must be integers
# Error collecting data for SeaCo: string indices must be integers
# Error collecting data for bdotdub: string indices must be integers
# Error collecting data for mpstaton: string indices must be integers
# Error collecting data for jiangxiaolei: string indices must be integers
# Error collecting data for madx: string indices must be integers
# Error collecting data for murilopontes: string indices must be integers
# Error collecting data for jklina: string indices must be integers
# Error collecting data for joenoon: string indices must be integers
# Error collecting data for jorgeortiz85: string indices must be integers
# Error collecting data for bits: string indices must be integers
# Error collecting data for lobo-tuerto: string indices must be integers
# Error collecting data for joestelmach: string indices must be integers
# Error collecting data for jfsantos: string indices must be integers
# Error collecting data for prlawrence: string indices must be integers
# Error collecting data for lucabastos: string indices must be integers
# Error collecting data for kumpera: string indices must be integers
# Error collecting data for awhitty: string indices must be integers
# Error collecting data for banbh: string indices must be integers
# Error collecting data for mauricio: string indices must be integers
# Error collecting data for glosie: string indices must be integers
# Error collecting data for wkorfhage: string indices must be integers
# Error collecting data for gordondaily: string indices must be integers
# Error collecting data for bts: string indices must be integers
# Error collecting data for slact: string indices must be integers
# Error collecting data for iry: string indices must be integers
# Error collecting data for josephsofaer: string indices must be integers
# Error collecting data for benjamn: string indices must be integers
# Error collecting data for jmcarthur: string indices must be integers
# Error collecting data for natsumi: string indices must be integers
# Error collecting data for yong: string indices must be integers
# Error collecting data for gar3thjon3s: string indices must be integers
# Error collecting data for fabiokung: string indices must be integers
# Error collecting data for trix: string indices must be integers
# Error collecting data for kuokon: string indices must be integers
# Error collecting data for gunark: string indices must be integers
# Error collecting data for zdk: string indices must be integers
# Error collecting data for imsaar: string indices must be integers
# Error collecting data for pdodds: string indices must be integers
# Error collecting data for scatterbrain: string indices must be integers
# Error collecting data for kjhealy: string indices must be integers
# Error collecting data for tremendo: string indices must be integers
# Error collecting data for eeejay: string indices must be integers
# Error collecting data for ufotofu: string indices must be integers
# Error collecting data for proc: string indices must be integers
# Error collecting data for brettjnorris: string indices must be integers
# Error collecting data for acunote: string indices must be integers
# Error collecting data for cjiang: string indices must be integers
# Error collecting data for fmeyer: string indices must be integers
# Error collecting data for KevinTriplett: string indices must be integers
# Error collecting data for mingtan: string indices must be integersError collecting data for tanimoto: string indices must be integers
#
# Error collecting data for pkordel: string indices must be integers
# Error collecting data for vyache: string indices must be integers
# Error collecting data for jorrel: string indices must be integers
# Error collecting data for sk1p: string indices must be integers
# Error collecting data for mert: string indices must be integers
# Error collecting data for franhb: string indices must be integers
# Error collecting data for cuda: string indices must be integers
# Error collecting data for valberg: string indices must be integers
# Error collecting data for chuonthis: string indices must be integers
# Error collecting data for jocke: string indices must be integers
# Error collecting data for kerray: string indices must be integers
# Error collecting data for janfrode: string indices must be integers
# Error collecting data for dubberx: string indices must be integers
# Error collecting data for joel: string indices must be integers
# Error collecting data for smmckay: string indices must be integers
# Error collecting data for lebigot: string indices must be integers
# Error collecting data for vasil: string indices must be integers
# Error collecting data for NeilW: string indices must be integers
# Error collecting data for ncr: string indices must be integers
# Error collecting data for kaminskipawel: string indices must be integers
# Error collecting data for beam: string indices must be integers
# Error collecting data for kij: string indices must be integers
# Error collecting data for tobyprivett: string indices must be integers
# Error collecting data for ben-xx: string indices must be integers
# Error collecting data for venkats: string indices must be integers
# Error collecting data for orienterare: string indices must be integers
# Error collecting data for ereboucas: string indices must be integers
# Error collecting data for ddeaguiar: string indices must be integers
# Error collecting data for dru: string indices must be integers
# Error collecting data for ryanraaum: string indices must be integers
# Error collecting data for tarellel: string indices must be integers
# Error collecting data for orkell: string indices must be integers
# Error collecting data for mario: string indices must be integers
# Error collecting data for bond: string indices must be integers
# Error collecting data for plomlompom: string indices must be integers
# Error collecting data for razrichter: string indices must be integers
# Error collecting data for ajaffer: string indices must be integers
# Error collecting data for yonen: string indices must be integers
# Error collecting data for tomaadland: string indices must be integers
# Error collecting data for peterlandry: string indices must be integers
# Error collecting data for mrtopf: string indices must be integers
# Error collecting data for pellegrino: string indices must be integers
# Error collecting data for gaustin: string indices must be integers
# Error collecting data for andypeters: string indices must be integers
# Error collecting data for greg-zz: string indices must be integers
# Error collecting data for jackscott: string indices must be integers
# Error collecting data for bschembri: string indices must be integers
# Error collecting data for rowland: string indices must be integers
# Error collecting data for sveiss: string indices must be integers
# Error collecting data for htp: string indices must be integers
# Error collecting data for hdp: string indices must be integers
# Error collecting data for gingerhendrix: string indices must be integers
# Error collecting data for jptoto: string indices must be integers
# Error collecting data for twjbmedia: string indices must be integers
# Error collecting data for jmonroe: string indices must be integers
# Error collecting data for psd: string indices must be integers
# Error collecting data for jacobat: string indices must be integers
# Error collecting data for stevej: string indices must be integers
# Error collecting data for JeanAzzopardi: string indices must be integers
# Error collecting data for isabanin: string indices must be integers
# Error collecting data for willvr: string indices must be integers
# Error collecting data for bartek: string indices must be integers
# Error collecting data for stuartloxton: string indices must be integers
# Error collecting data for 19WAS85: string indices must be integers
# Error collecting data for mattwigham: string indices must be integers
# Error collecting data for FunkeyMonkeys: string indices must be integers
# Error collecting data for anselmo: string indices must be integers
# Error collecting data for vivekamn: string indices must be integers
# Error collecting data for Apreche: string indices must be integers
# Error collecting data for mech: string indices must be integers
# Error collecting data for mico: string indices must be integers
# Error collecting data for bradclawsie: string indices must be integers
# Error collecting data for dario-xx: string indices must be integers
# Error collecting data for trevorgerzen: string indices must be integers
# Error collecting data for anderson: string indices must be integers
# Error collecting data for trms: string indices must be integers
# Error collecting data for aiqbal: string indices must be integers
# Error collecting data for marsuboss: string indices must be integers
# Error collecting data for abbot: string indices must be integers
# Error collecting data for jailton: string indices must be integers
# Error collecting data for dbrajkovic: string indices must be integers
# Error collecting data for etnt: string indices must be integers
# Error collecting data for bbrown: string indices must be integers
# Error collecting data for Illydth: string indices must be integers
# Error collecting data for philhawksworth: string indices must be integers
# Error collecting data for siong1987: string indices must be integers
# Error collecting data for rgiaviti: string indices must be integers
# Error collecting data for karmatr0n: string indices must be integers
# Error collecting data for seannui: string indices must be integers
# Error collecting data for vmukhin: string indices must be integers
# Error collecting data for jweiss: string indices must be integers
# Error collecting data for RSpace: string indices must be integers
# Error collecting data for devlin: string indices must be integers
# Error collecting data for hashrocket: string indices must be integers
# Error collecting data for Bitsonnet: string indices must be integers
# Error collecting data for fain182: string indices must be integers
# Error collecting data for phedders: string indices must be integers
# Error collecting data for pbacgrad: string indices must be integers
# Error collecting data for gregspurrier: string indices must be integers
# Error collecting data for vonglod: string indices must be integers
# Error collecting data for cristianosanchez: string indices must be integers
# Error collecting data for millnitz: string indices must be integers
# Error collecting data for jeremy-kunzhou: string indices must be integers
# Error collecting data for jared-is-ray: string indices must be integers
# Error collecting data for alexb-zz: string indices must be integers
# Error collecting data for kar8nga: string indices must be integers
# Error collecting data for davidn: string indices must be integers
# Error collecting data for jolly-zz: string indices must be integers
# Error collecting data for futuremint: string indices must be integers
# Error collecting data for Fluxx: string indices must be integers
# Error collecting data for kelvie: string indices must be integers
# Error collecting data for oniony: string indices must be integers
# Error collecting data for setanta: string indices must be integers
# Error collecting data for thecruller: string indices must be integers
# Error collecting data for kvirani: string indices must be integers
# Error collecting data for jordanisip: string indices must be integers
# Error collecting data for seemiller: string indices must be integers
# Error collecting data for wiecknick: string indices must be integers
# Error collecting data for skanthak: string indices must be integers
# Error collecting data for benhanzl: string indices must be integers
# Error collecting data for tobas: string indices must be integers
# Error collecting data for sgarza: string indices must be integers
# Error collecting data for whalesalad: string indices must be integers
# Error collecting data for justinvt: string indices must be integers
# Error collecting data for jgoizueta: string indices must be integers
# Error collecting data for antomonte: string indices must be integers
# Error collecting data for jrylander: string indices must be integers
# Error collecting data for TylerWhittaker: string indices must be integers
# Error collecting data for thepiratebae: string indices must be integers
# Error collecting data for ozgun: string indices must be integers
# Error collecting data for sjaq: string indices must be integers
# Error collecting data for wickkidd: string indices must be integers
# Error collecting data for cyberfox: string indices must be integers
# Error collecting data for jmatt: string indices must be integers
# Error collecting data for bauerpl: string indices must be integers
# Error collecting data for mbrubeck: string indices must be integers
# Error collecting data for buckett: string indices must be integers
# Error collecting data for kortina: string indices must be integers
# Error collecting data for steveaba: string indices must be integers
# Error collecting data for lenards: string indices must be integers
# Error collecting data for mhp: string indices must be integers
# Error collecting data for gcheadle: string indices must be integers
# Error collecting data for fcheung: string indices must be integers
# Error collecting data for ciriarte: string indices must be integers
# Error collecting data for eriko: string indices must be integers
# Error collecting data for jdo: string indices must be integers
# Error collecting data for jmay: string indices must be integers
# Error collecting data for GeertClaes: string indices must be integers
# Error collecting data for kiff100: string indices must be integers
# Error collecting data for jamesbebbington: string indices must be integers
# Error collecting data for andre: string indices must be integers
# Error collecting data for chaupt: string indices must be integers
# Error collecting data for liquidautumn: string indices must be integers
# Error collecting data for dynamix: string indices must be integers
# Error collecting data for vietual: string indices must be integers
# Error collecting data for AndrewTosh: string indices must be integers
# Error collecting data for FotoVerite: string indices must be integers
# Error collecting data for NigelThorne: string indices must be integers
# Error collecting data for nominolo: string indices must be integers
# Error collecting data for robotButler: string indices must be integers
# Error collecting data for trevor: string indices must be integers
# Error collecting data for zero51: string indices must be integers
# Error collecting data for jesse: string indices must be integers
# Error collecting data for funkfinger: string indices must be integers
# Error collecting data for Mystic: string indices must be integers
# Error collecting data for callumbaillie: string indices must be integers
# Error collecting data for tjriley: string indices must be integers
# Error collecting data for cnk: string indices must be integers
# Error collecting data for ericc59: string indices must be integers
# Error collecting data for foobar: string indices must be integers
# Error collecting data for djuggler: string indices must be integers
# Error collecting data for Taeril: string indices must be integers
# Error collecting data for juanger: string indices must be integers
# Error collecting data for zhangxue: string indices must be integers
# Error collecting data for janx: string indices must be integers
# Error collecting data for poshboytl: string indices must be integers
# Error collecting data for devraj: string indices must be integers
# Error collecting data for sausheong: string indices must be integers
# Error collecting data for cultofmetatron: string indices must be integers
# Error collecting data for nextalias: string indices must be integers
# Error collecting data for pavanagrawal: string indices must be integers
# Error collecting data for rvalente: string indices must be integers
# Error collecting data for dekart: string indices must be integers
# Error collecting data for quannon: string indices must be integers
# Error collecting data for wukao1985: string indices must be integers
# Error collecting data for arex: string indices must be integersError collecting data for flogic: string indices must be integers
#
# Error collecting data for Yuancheng: string indices must be integers
# Error collecting data for mpowered: string indices must be integers
# Error collecting data for antenore: string indices must be integers
# Error collecting data for Cui: string indices must be integers
# Error collecting data for kdwinter: string indices must be integers
# Error collecting data for brotherlogic: string indices must be integers
# Error collecting data for Electron-libre: string indices must be integers
# Error collecting data for mojek: string indices must be integers
# Error collecting data for Hemant-zz: string indices must be integers
# Error collecting data for ianwhite: string indices must be integers
# Error collecting data for ryebread: string indices must be integers
# Error collecting data for rdrainville: string indices must be integers
# Error collecting data for zed-0xff: string indices must be integers
# Error collecting data for obeattie: string indices must be integers
# Error collecting data for beef: string indices must be integers
# Error collecting data for gregori: string indices must be integers
# Error collecting data for Arnauh: string indices must be integers
# Error collecting data for slaskis: string indices must be integers
# Error collecting data for deugarte: string indices must be integers
# Error collecting data for mike-hogan: string indices must be integers
# Error collecting data for enrico: string indices must be integers
# Error collecting data for przeor: string indices must be integers
# Error collecting data for RalphD: string indices must be integers
# Error collecting data for jefmsmit: string indices must be integers
# Error collecting data for johnl: string indices must be integers
# Error collecting data for mvivekan: string indices must be integers
# Error collecting data for nicolas: string indices must be integers
# Error collecting data for pirelenito: string indices must be integers
# Error collecting data for bcalloway: string indices must be integers
# Error collecting data for dhainlin: string indices must be integers
# Error collecting data for marcin: string indices must be integers
# Error collecting data for pablohart: string indices must be integers
# Error collecting data for rrooding: string indices must be integers
# Error collecting data for sheikhomar: string indices must be integers
# Error collecting data for eagleeye87: string indices must be integers
# Error collecting data for neuromancer74: string indices must be integers
# Error collecting data for SalesLentz: string indices must be integers
# Error collecting data for pkondzior: string indices must be integers
# Error collecting data for ssurfer: string indices must be integers
# Error collecting data for rafaelsteil: string indices must be integers
# Error collecting data for loranger: string indices must be integers
# Error collecting data for pnowak2: string indices must be integers
# Error collecting data for atonse: string indices must be integers
# Error collecting data for coolbeansdude51: string indices must be integers
# Error collecting data for cryptobenkei: string indices must be integers
# Error collecting data for jprieur: string indices must be integers
# Error collecting data for Florian95: string indices must be integers
# Error collecting data for ubercolin: string indices must be integers
# Error collecting data for ziz: string indices must be integers
# Error collecting data for garrettmurray: string indices must be integers
# Error collecting data for jhaynie: string indices must be integers
# Error collecting data for nelsonsilva: string indices must be integers
# Error collecting data for jcoppedge1: string indices must be integers
# Error collecting data for steadicat: string indices must be integers
# Error collecting data for kmoragas: string indices must be integers
# Error collecting data for teyo: string indices must be integers
# Error collecting data for jasonpenny: string indices must be integers
# Error collecting data for jibubo: string indices must be integers
# Error collecting data for ja30278: string indices must be integers
# Error collecting data for sliver: string indices must be integers
# Error collecting data for triplef: string indices must be integers
# Error collecting data for jbcrail: string indices must be integers
# Error collecting data for mikE83: string indices must be integers
# Error collecting data for henryhamon: string indices must be integers
# Error collecting data for danhollywells: string indices must be integers
# Error collecting data for exzackley: string indices must be integers
# Error collecting data for n8agrin: string indices must be integers
# Error collecting data for asierra: string indices must be integers
# Error collecting data for inz: string indices must be integers
# Error collecting data for pollutionisgreat: string indices must be integers
# Error collecting data for derekmahar: string indices must be integers
# ...
# Error collecting data for koolontheweblog: string indices must be integers
# Error collecting data for jgp: string indices must be integers
# Error collecting data for mikerowlands: string indices must be integers
# Error collecting data for arunalangar: string indices must be integers
# Error collecting data for karin: string indices must be integers
# Error collecting data for mattjamieson: string indices must be integers
# Error collecting data for modano: string indices must be integers
# Error collecting data for philippschmidt: string indices must be integers
# Error collecting data for geirlandro: string indices must be integers
# Error collecting data for ckade: string indices must be integers
# Error collecting data for mihaidoru: string indices must be integers
# Error collecting data for VGraupera: string indices must be integers
# Error collecting data for puria: string indices must be integers
# Error collecting data for nide: string indices must be integers
# Error collecting data for marcelo: string indices must be integers
# Error collecting data for scorley: string indices must be integers
# Error collecting data for skanev: string indices must be integers
# Error collecting data for dwoodman2008: string indices must be integers
# Error collecting data for shaobin0604: string indices must be integers
# Error collecting data for bene-zz: string indices must be integers
# Error collecting data for aeclean: string indices must be integers
# Error collecting data for wilco: string indices must be integers
# Error collecting data for dob: string indices must be integers
# Error collecting data for philipefarias: string indices must be integers
# Error collecting data for tsekhotsky: string indices must be integers
# Error collecting data for digitaleprodukter: string indices must be integers
# Error collecting data for dusk: string indices must be integers
# Error collecting data for pbrain: string indices must be integers
# Error collecting data for hamatosan: string indices must be integers
# Error collecting data for tdenkinger: string indices must be integers
# Error collecting data for okaq: string indices must be integers
# Error collecting data for esofomuso: string indices must be integers
# Error collecting data for takahashim: string indices must be integers
# Error collecting data for frogmetrics: string indices must be integers
# Error collecting data for otheriault: string indices must be integers
# Error collecting data for cjolly: string indices must be integers
# Error collecting data for delonnewman: string indices must be integers
# Error collecting data for lamon: string indices must be integers
# Error collecting data for apotonick: string indices must be integers
# Error collecting data for digimedia: string indices must be integers
# Error collecting data for olsonjeffery: string indices must be integers
# Error collecting data for apeiros: string indices must be integers
# Error collecting data for mgrosello: string indices must be integers
# Error collecting data for shannonpubdisplay: string indices must be integers
# Error collecting data for jchristopher: string indices must be integers
# Error collecting data for Hemphill: string indices must be integers
# Error collecting data for shawncheatham: string indices must be integers
# Error collecting data for waldek: string indices must be integers
# Error collecting data for min: string indices must be integers
# Error collecting data for godfat: string indices must be integers
# Error collecting data for SabotageMedia: string indices must be integers
# Error collecting data for ajh: string indices must be integers
# Error collecting data for finster: string indices must be integers
# Error collecting data for devn: string indices must be integers
# Error collecting data for mic: string indices must be integers
# Error collecting data for dmitrig01: string indices must be integers
# Error collecting data for johnsonch: string indices must be integers
# Error collecting data for matjaz: string indices must be integers
# Error collecting data for thunder75: string indices must be integers
# Error collecting data for dojosp: string indices must be integers
# Error collecting data for ruuzo: string indices must be integers
# Error collecting data for zzed: string indices must be integers
# Error collecting data for chrissutton: string indices must be integers
# Error collecting data for shari: string indices must be integers
# Error collecting data for jeremymims: string indices must be integers
# Error collecting data for bpalmen: string indices must be integers
# Error collecting data for Zounas: string indices must be integers
# Error collecting data for khalid-zz: string indices must be integers
# Error collecting data for just3ws: string indices must be integers
# Error collecting data for seanhussey: string indices must be integers
# Error collecting data for dewittn: string indices must be integers
# Error collecting data for dzfl: string indices must be integers
# Error collecting data for cliffrh: string indices must be integers
# Error collecting data for paccoxs: string indices must be integers
# Error collecting data for nateirwin: string indices must be integers
# Error collecting data for visnup: string indices must be integers
# Error collecting data for luxre: string indices must be integers
# Error collecting data for iamwilhelm: string indices must be integers
# Error collecting data for belshire: string indices must be integers
# Error collecting data for debra: string indices must be integers
# Error collecting data for PixelRobot: string indices must be integers
# Error collecting data for trowe: string indices must be integers
# Error collecting data for mjudge: string indices must be integers
# Error collecting data for wprater: string indices must be integers
# Error collecting data for datafirm: string indices must be integers
# Error collecting data for wiwat: string indices must be integers
# Error collecting data for eggy: string indices must be integers
# Error collecting data for aazar: string indices must be integers
# Error collecting data for nimamdb: string indices must be integers
# Error collecting data for prem: string indices must be integers
# Error collecting data for ttdonovan: string indices must be integers
# Error collecting data for davidbody: string indices must be integers
# Error collecting data for dmullins78: string indices must be integers
# Error collecting data for pclowser: string indices must be integers
# Error collecting data for benpetro: string indices must be integers
# Error collecting data for schmitzc: string indices must be integers
# Error collecting data for krupenik: string indices must be integers
# Error collecting data for dbarale: string indices must be integers
# Error collecting data for rchk: string indices must be integers
# Error collecting data for dou: string indices must be integers
# Error collecting data for stuartyeates: string indices must be integers
# Error collecting data for jwesselman: string indices must be integers
# Error collecting data for oldaccounttodelete: string indices must be integers
# Error collecting data for alvisbjones: string indices must be integers
# Error collecting data for stassats: string indices must be integers
# Error collecting data for webiest: string indices must be integers
# Error collecting data for macdigger: string indices must be integers
# Error collecting data for dmangiarelli: string indices must be integers
# Error collecting data for cmarcelo: string indices must be integers
# Error collecting data for andrewcurtis: string indices must be integers
# Error collecting data for naven87: string indices must be integers
# Error collecting data for jkestr: string indices must be integers
# Error collecting data for pkinsel: string indices must be integers
# Error collecting data for felipc: string indices must be integers
# Error collecting data for spiridon: string indices must be integers
# Error collecting data for bto: string indices must be integers
# Error collecting data for suzuki: string indices must be integers
# Error collecting data for front-end: string indices must be integers
# Error collecting data for selva: string indices must be integers
# Error collecting data for rpm33: string indices must be integers
# Error collecting data for kamme: string indices must be integers
# Error collecting data for slain: string indices must be integers
# Error collecting data for selim13: string indices must be integers
# Error collecting data for jpradxx: string indices must be integers
# Error collecting data for oli: string indices must be integers
# Error collecting data for daniel-kun: string indices must be integers
# Error collecting data for resshin: string indices must be integers
# Error collecting data for macovsky: string indices must be integers
# Error collecting data for ZenCocoon: string indices must be integers
# Error collecting data for noj: string indices must be integers
# Error collecting data for psynaptic: string indices must be integers
# Error collecting data for adamhenry: string indices must be integers
# Error collecting data for telenieko: string indices must be integers
# Error collecting data for hjaltij: string indices must be integers
# Error collecting data for sjelfull: string indices must be integers
# Error collecting data for ryankv: string indices must be integers
# Error collecting data for leandro: string indices must be integers
# Error collecting data for diino: string indices must be integers
# Error collecting data for timecode: string indices must be integers
# Error collecting data for madnificent: string indices must be integers
# Error collecting data for nud: string indices must be integers
# Error collecting data for gorodetskiy: string indices must be integers
# Error collecting data for frankmt: string indices must be integers
# Error collecting data for kyanny: string indices must be integers
# Error collecting data for jwall: string indices must be integers
# Error collecting data for kevin5jan: string indices must be integersError collecting data for Fabs: string indices must be integers
#
# Error collecting data for kmikolaj: string indices must be integers
# Error collecting data for andydude: string indices must be integers
# Error collecting data for skorecky: string indices must be integers
# Error collecting data for kakuda: string indices must be integers
# Error collecting data for dmadmin: string indices must be integers
# Error collecting data for jlamons: string indices must be integers
# Error collecting data for amitava: string indices must be integers
# Error collecting data for papa99do: string indices must be integers
# Error collecting data for osterwood: string indices must be integers
# Error collecting data for DinoHQ: string indices must be integers
# Error collecting data for Adtegrity: string indices must be integers
# Error collecting data for johntajima: string indices must be integers
# Error collecting data for akr: string indices must be integers
# Error collecting data for nlanier001: string indices must be integers
# Error collecting data for himi: string indices must be integers
# Error collecting data for bo198214: string indices must be integers
# Error collecting data for jjneely: string indices must be integers
# Error collecting data for ryankshaw: string indices must be integers
# Error collecting data for ktf: string indices must be integers
# Error collecting data for amosson: string indices must be integers
# Error collecting data for danieldocki: string indices must be integers
# Error collecting data for germ: string indices must be integers
# Error collecting data for bleepbloop: string indices must be integers
# Error collecting data for seaver: string indices must be integersError collecting data for synth: string indices must be integers
#
# Error collecting data for video: string indices must be integers
# Error collecting data for hecht: string indices must be integers
# Error collecting data for cpb: string indices must be integers
# Error collecting data for adamdarton: string indices must be integers
# Error collecting data for watcher: string indices must be integers
# Error collecting data for lizbaron: string indices must be integers
# Error collecting data for kofi: string indices must be integers
# Error collecting data for hitsvilleusa: string indices must be integers
# Error collecting data for mlednor: string indices must be integers
# Error collecting data for mch974: string indices must be integers
# Error collecting data for matiasleidemer: string indices must be integers
# Error collecting data for jetulis: string indices must be integers
# Error collecting data for vassiliad: string indices must be integers
# Error collecting data for thebugslayer: string indices must be integers
# Error collecting data for positivelabs: string indices must be integers
# Error collecting data for kzmkv: string indices must be integers
# Error collecting data for erikhansson: string indices must be integers
# Error collecting data for ramji: string indices must be integers
# Error collecting data for etdebruin: string indices must be integers
# Error collecting data for atmacat: string indices must be integers
# Error collecting data for ajdramos: string indices must be integers
# Error collecting data for eaevans: string indices must be integers
# Error collecting data for dpp: string indices must be integers
# Error collecting data for niyogi: string indices must be integers
# Error collecting data for tomas: string indices must be integers
# Error collecting data for citris: string indices must be integers
# Error collecting data for katylava: string indices must be integers
# Error collecting data for pgm: string indices must be integers
# Error collecting data for madanr: string indices must be integers
# Error collecting data for shmz: string indices must be integers
# Error collecting data for eightbitcollective: string indices must be integers
# Error collecting data for trash80: string indices must be integers
# Error collecting data for kataring: string indices must be integers
# Error collecting data for arton: string indices must be integers
# Error collecting data for turgon: string indices must be integers
# Error collecting data for lefsy: string indices must be integers
# Error collecting data for Evanlec: string indices must be integers
# Error collecting data for elementcreative: string indices must be integers
# Error collecting data for direction: string indices must be integers
# Error collecting data for ato: string indices must be integers
# Error collecting data for LunAnder: string indices must be integers
# Error collecting data for danoph: string indices must be integers
# Error collecting data for Cas1337: string indices must be integers
# Error collecting data for ilgimgurel: string indices must be integers
# Error collecting data for maniacboxer: string indices must be integers
# Error collecting data for ryokucha: string indices must be integers
# Error collecting data for delor: string indices must be integers
# Error collecting data for jeans: string indices must be integers
# Error collecting data for voss: string indices must be integers
# Error collecting data for kelyar: string indices must be integers
# Error collecting data for ketan: string indices must be integers
# Error collecting data for odorovic: string indices must be integers
# Error collecting data for nimish-xx: string indices must be integers
# Error collecting data for watson: string indices must be integers
#   profile_name  followers  public_repos  total_stars  total_forks  \
# 0     ezmobius        554            22         1574          193
# 1      pjhyett       8273             8          606          147
# 2      mojombo      23884            66        10265         2238
# 3      defunkt      22281           107         8664         1504
# 4         ivey        149            37           83           15
#
#    contributions_today  streak_maintained  rating
# 0                    0                  0    5.84
# 1                    0                  0    6.98
# 2                    0                  0    8.98
# 3                    0                  0   10.00
# 4                    0                  0    2.11

# %%
rating = followers_score + public_repos_score + stars_score + forks_score + streak_score

# %%
data.head(4)
# Out:
#   profile_name  followers  public_repos  total_stars  total_forks  \
# 0     ezmobius        554            22         1574          193
# 1      pjhyett       8273             8          606          147
# 2      mojombo      23884            66        10265         2238
# 3      defunkt      22281           107         8664         1504
#
#    contributions_today  streak_maintained  rating
# 0                    0                  0    5.84
# 1                    0                  0    6.98
# 2                    0                  0    8.98
# 3                    0                  0   10.00

# %%
# Prepare data for model training
X = data.drop(columns = ['rating' , 'profile_name','contributions_today'], axis=1)
y = data['rating']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.0834, random_state=42)

# Train model
model = RandomForestRegressor()
model.fit(X_train, y_train)

# Evaluate model
predictions = model.predict(X_test)
print('MSE:', mean_squared_error(y_test, predictions))

# Save the model
joblib.dump(model, 'github_profile_rating_model.pkl')
# Out:
# MSE: 0.19301618843750085
# ['github_profile_rating_model.pkl']

# %%
model = joblib.load('github_profile_rating_model.pkl')

# %%
pred = model.predict([[8273,	8	,606,	147,	0	]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
pred # In reality 5.86
# Out:
# array([7.2348])
